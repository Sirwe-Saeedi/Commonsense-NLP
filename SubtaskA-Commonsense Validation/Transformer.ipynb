# %% [markdown]
# #Tesla

# %%
# !nvidia-smi | grep "|   0"
# Out:
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |

# %% [markdown]
# #Updating Stuff

# %%
# Make ready for fast.ai
# !curl -s https://course.fast.ai/setup/colab | bash
# !pip -q install git+https://github.com/fastai/fastai.git -U
# Out:
# Updating fastai...
# Done.
#   Building wheel for fastai (setup.py) ... done

# %% [markdown]
# #Importing Libraries

# %%
import fastai
from fastai.text import *
from fastai import *
import pandas as pd
import glob
from numpy import random

# %% [markdown]
# #Downloading and preparing Traning Data

# %% [markdown]
# ##Downloading CSV files from task4 repo

# %%
subtaskA_URL = 'https://raw.githubusercontent.com/wangcunxiang/SemEval2020-Task4-Commonsense-Validation-and-Explanation/master/Training%20%20Data/subtaskA_data_all.csv'

# %%
subtaskA_Answers_URL = 'https://raw.githubusercontent.com/wangcunxiang/SemEval2020-Task4-Commonsense-Validation-and-Explanation/master/Training%20%20Data/subtaskA_answers_all.csv'

# %%
import urllib.request
urllib.request.urlretrieve(subtaskA_URL , '/content/subtaskA_data_all.csv')
# Out:
# ('/content/subtaskA_data_all.csv', <http.client.HTTPMessage at 0x7f2b98256e10>)

# %%
urllib.request.urlretrieve(subtaskA_Answers_URL , '/content/subtaskA_answers_all.csv')
# Out:
# ('/content/subtaskA_answers_all.csv',
#  <http.client.HTTPMessage at 0x7f2b98268ef0>)

# %% [markdown]
# ##Read subtaskA_data_all.csv
# subtaskA_data_all is the released training set of this task

# %%
df1 = pd.read_csv(subtaskA_URL , index_col=0)
df1
# Out:
#                                                   sent0                                              sent1
# id
# 0                 He poured orange juice on his cereal.                      He poured milk on his cereal.
# 1                                      He drinks apple.                                    He drinks milk.
# 2                                 Jeff ran a mile today                       Jeff ran 100,000 miles today
# 3                                  A mosquito stings me                                 I sting a mosquito
# 4                                  A niece is a person.                             A giraffe is a person.
# ...                                                 ...                                                ...
# 9995                   Mark ate a big bitter cherry pie                    Mark ate a big sweet cherry pie
# 9996                     Gloria wears a cat on her head                     Gloria wears a hat on her head
# 9997  Harry went to the barbershop to have his hair cut  Harry went to the barbershop to have his glass...
# 9998                    Reilly is sleeping on the couch                   Reilly is sleeping on the window
# 9999                           I have a desk on my lamp                           I have a lamp on my desk
#
# [10000 rows x 2 columns]

# %%
#df1['Sentences_Seperated'] = df1[['sent0', 'sent1']].apply(lambda x: ' , '.join(x), axis=1)
#df1.drop(['sent0' , 'sent1'], axis=1, inplace=True)
#df1

# %% [markdown]
# ##Read subtaskA_answers_all.csv
#
# The labels are given in a different csv file

# %%
df2 = pd.read_csv(subtaskA_Answers_URL , header=None)
df2.columns = ['id', 'answers']
df2.set_index('id', inplace=True)
df2
# Out:
#       answers
# id
# 0           0
# 1           0
# 2           1
# 3           1
# 4           1
# ...       ...
# 9995        0
# 9996        0
# 9997        1
# 9998        1
# 9999        0
#
# [10000 rows x 1 columns]

# %% [markdown]
# ##Dataframe
# The final dataframe/Training set

# %%
df = df1.merge(df2 , on='id')
df['predicted_answers'] = None
#df = df.assign(predicted_answers = np.nan)
df
# Out:
#                                                   sent0  ... predicted_answers
# id                                                       ...
# 0                 He poured orange juice on his cereal.  ...              None
# 1                                      He drinks apple.  ...              None
# 2                                 Jeff ran a mile today  ...              None
# 3                                  A mosquito stings me  ...              None
# 4                                  A niece is a person.  ...              None
# ...                                                 ...  ...               ...
# 9995                   Mark ate a big bitter cherry pie  ...              None
# 9996                     Gloria wears a cat on her head  ...              None
# 9997  Harry went to the barbershop to have his hair cut  ...              None
# 9998                    Reilly is sleeping on the couch  ...              None
# 9999                           I have a desk on my lamp  ...              None
#
# [10000 rows x 4 columns]

# %% [markdown]
# ##If you want to use from_csv

# %%
#Writing a pandas DataFrame to CSV file
# df.to_csv("training_all.csv")

# %%
# df[0:8000]

# %% [markdown]
# #Seperate training set & test set & validation set
#
# 8000 sampels for training data , 1000 sampels for validation data, 1000 samples for test data

# %%
df_training = df[0:8000]
df_valid = df[8000:9000]
df_test = df[9000:10000]
df_test = df_test.drop( 'answers' , axis = 1)
df_training
# Out:
#                                        sent0  ... predicted_answers
# id                                            ...
# 0      He poured orange juice on his cereal.  ...              None
# 1                           He drinks apple.  ...              None
# 2                      Jeff ran a mile today  ...              None
# 3                       A mosquito stings me  ...              None
# 4                       A niece is a person.  ...              None
# ...                                      ...  ...               ...
# 7995  you can use the pitcher to drink water  ...              None
# 7996             I put my books in a shoebox  ...              None
# 7997            a kitchen is a place to cook  ...              None
# 7998           refrigerators can heat drinks  ...              None
# 7999               flowers will fall someday  ...              None
#
# [8000 rows x 4 columns]

# %%
df_valid
# Out:
#                                                   sent0  ... predicted_answers
# id                                                       ...
# 8000           New York is the capital city of Illinois  ...              None
# 8001  The poor countries are more livable than in ri...  ...              None
# 8002          Staying up late is harmful to our health.  ...              None
# 8003                        Studying hardly is useless.  ...              None
# 8004                    a little baby can't feed itself  ...              None
# ...                                                 ...  ...               ...
# 8995     she put her earrings back to the seasoning box  ...              None
# 8996  a short lunch break from work makes me eat qui...  ...              None
# 8997  every time I got a reply when he received my l...  ...              None
# 8998  they were not satisfied with each other and go...  ...              None
# 8999           the waiter gave him a menu to order food  ...              None
#
# [1000 rows x 4 columns]

# %%
df_test
# Out:
#                                                   sent0  ... predicted_answers
# id                                                       ...
# 9000               he lit a torch to see in the daytime  ...              None
# 9001         I put all my stuff in the drawer to travel  ...              None
# 9002     he used a blow dryer before he washed his hair  ...              None
# 9003                     he used chopsticks to eat soup  ...              None
# 9004               DVD can be used to store information  ...              None
# ...                                                 ...  ...               ...
# 9995                   Mark ate a big bitter cherry pie  ...              None
# 9996                     Gloria wears a cat on her head  ...              None
# 9997  Harry went to the barbershop to have his hair cut  ...              None
# 9998                    Reilly is sleeping on the couch  ...              None
# 9999                           I have a desk on my lamp  ...              None
#
# [1000 rows x 3 columns]

# %% [markdown]
# ##If you want to use from_csv

# %%
df_training.to_csv("training.csv")
df_test.to_csv("test.csv")
df_valid.to_csv("valid.csv")
df_training['sent0']
# Out:
# id
# 0        He poured orange juice on his cereal.
# 1                             He drinks apple.
# 2                        Jeff ran a mile today
# 3                         A mosquito stings me
# 4                         A niece is a person.
#                          ...
# 7995    you can use the pitcher to drink water
# 7996               I put my books in a shoebox
# 7997              a kitchen is a place to cook
# 7998             refrigerators can heat drinks
# 7999                 flowers will fall someday
# Name: sent0, Length: 8000, dtype: object

# %%
for i in range(8000):
  print(df_training['sent0'][i])
# Out:
# He poured orange juice on his cereal.
# He drinks apple.
# Jeff ran a mile today
# A mosquito stings me
# A niece is a person.
# A walk-in closet is larger than a normal closet.
# I like to ride my chocolate
# A GIRL WON THE RACE WITH HER FRIEND
# he put elephant into the jug
# A girl plays volleyball
# Eggs eat kis on Easter.
# Mark drank a notebook.
# He went to the police station to withdraw cash.
# An owner can price goods
# she wear bangles in the hand
# My cousin throws the snowball to my brother.
# The caterpillar eats the rose bud
# Lisa played jazz music for Moses of the Old Testament yesterday.
# the computer broke down and the doctor fixed it
# I drank bleach.
# I usually wear a shoe on my head
# My brother placed the car inside the box.
# She took the chair for a walk
# A dog barked at a cat in the street.
# He mowed the carpet
# I drive a bike
# I dress an elephant
# I cook fish very well
# Car is a very good mode of water transport
# a dog is taken to a veterinarian after getting sick
# She rode her bike to the moon.
# A mobile phone shut down
# He planted cucumber seeds in the couch.
# I play games on my Gas stove
# I read stars
# A boy turns off the door
# He read a very long window King Tut.
# He lost his phone at the park.
# Sara had a glass of water
# he kept a juice bottle into the fridge
# I read a tiger
# I use internet on my radio
# She drove her children to the moon.
# She drove to the grocery store.
# The fish swam in the desert.
# There was a man walking in the snow.
# I swim under a tap
# A person eats tomatoes
# Jane saw a giraffe at the zoo.
# We use a clock to know the time
# I was playing basketball with a ball
# Mary took her dog for a walk
# I like to listen podcasts as I commute
# I run in the air
# There was a blonde woman riding a dragon.
# He ate the book
# Jake ate artificial mango
# Baby is taking toys
# the school was open for summer
# The chocolate cried
# There are commercials in the middle of a television program
# He was tired and so he went to get into his car.
# You sometimes puke after getting drunk
# You can use a jellyfish to hold checks.
# Lawyers are people who play characters in television or theatre
# A giraffe drove a car
# A small dog is called a kitten
# The parrot went to work
# My daughter always takes bath in a kitchen sink and avoids bath tub
# He killed him with a knife
# The cinema shared popcorn with them
# Rotten food usually smells nasty.
# An actor wear a toaster.
# The man slept in bed.
# She spoke to a ghost at the door.
# You will never see a teacher inside of a school.
# She cuts a pizza with a knife.
# They built the sun
# The man put some muffins in the microwave
# There was a chicken flying.
# He played the cow very well
# If your heartbeat stops then you are classed as dead.
# the trampoline jumped on him
# Georgia Tech is a school.
# She was going to school in a bus
# The moon turns full about once a month
# The man paid the bill with cash.
# You are cooking the dinner
# She write the story in paper
# The storage in every computer is unlimited.
# People only cry when they are angry.
# Most people like to have coffee and doughnuts in the morning.
# Frank hit Will with a stone causing him pain
# he put the sock on the drum.
# he shaved his teeth
# She put mustard on a star.
# they put on shoes to walk outside
# He was playing music
# A person can visit relatives.
# Tight shoes are comfortable.
# Low blood pressure is a hazardous way to diet and lose weight.
# Plants can make computers
# My friend like to eat non-veg food
# He cooks a bed in the pan.
# Dirty dishes cannot be cleaned in a dishwasher.
# He put a cat into the cabinet.
# The girl likes to eat sweets.
# The cat barked at the mailman.
# If you drink a lot in the pub you will become drunk
# The woman played television
# The eagle flies deep in the ocean
# She went to the park on Sunday
# 200 is one hundred
# She ran on the track.
# he drank apple juice
# The girl was sleeping on a couch
# I typed something on the floor
# The plane flew to Belize
# He visited a dentist to check his tooth pain
# The dog goes flying three times a day.
# You need to buy a ticket to enter a cinema
# He didn't want to leave from inside his mailbox.
# He unlocked the door with a shoe.
# He took his dog to the hairdresser for a health check-up.
# One of the things you do when you wake up is brushing your teeth
# The Children were happy seeing the clown
# He carved the ham with a knife.
# He took his dog to the veterinary to take his vaccines
# In the morning when I wake up, I eat breakfast.
# Potatos is the plural of potato
# I found a notepad on a table.
# Something you might do while driving your car is slam on the brakes
# People went to restaurant to pray
# He called the police to complain about the robber
# Curtains let more light into the room.
# He sent a text message in lunch box
# An armchair is where people sit and relax
# He was sentenced to death in a trial.
# He drinks petrol every morning
# James read the last page of the book, and put it back on the book shelf.
# She drove her car around the supermarket to collect groceries
# You can see pictures in a museum
# He packed his clothes in a pen
# She put her shoes on her feet
# He bought plate to cook food
# I want to play football on my guitar
# The student copied his professors notes.
# Mobiles are used to cleaning
# A bed is used for sleeping
# My friend drank juice in a glass.
# She put a pie in the oven.
# She was eating shoe
# She got into the bathtub to sleep.
# She put a pizza in the oven.
# Umbrella is used during a rainy day.
# we can cook food in the kitchen
# Food baked longer than recommended can burn
# Jim drove to the mall
# She heated up the water to make tea.
# A sword is a weapon
# A planet has a square shape
# He put frozen turkey in the freezer.
# Grass is green
# Most plants have green leaves.
# The doctor gave vaccine through injection
# My house is homosexual.
# You can buy cigarettes in bottles
# Eating lot of food makes you fat
# Adjectives are a part of speech
# It rains occasionally which is horrible for the trees and grass.
# If she is dead she will buy a new house.
# The dog jumped over a log.
# She worked out the question on the calculator
# She hung an elevator on the wall.
# Anxiety disorders affect around 10% of people at any one time.
# Boats sail on the water.
# Burglars are good people
# I wore a black tie to the funeral
# The Students Scolded the Teacher
# They switched on the stove to watch their favourite programme
# he kept ice cream in oven
# She was frying the nuts in hot pan
# Learning a language is easy
# Michelle put a TV in the back of her car.
# you will find a rock in a mountain
# The ferry crossed the river on the car.
# The rain made my t-shirt wet.
# she was swimming in hot oil.
# Bella loves to dance in a ballroom in her pink car.
# Eggs are usually used as cricket ball
# One thing you will see at a Tyre change shop is a compressor
# Umbrellas are good means of communication
# Winter coats are helpful in cold temperatures.
# He ate an apple
# Pencils contain a chocolate core
# he cut the cheese with knife
# He took his family to restaurant for dinner
# Players play soccer with sports shoes
# His reflection was invisible in the mirror.
# He was eating hotdogs
# I will play the table in class tomorrow in front of students
# A lathe is used to shape material.
# Water is a drink with brown colour
# People use computer to make money.
# A policeman carries a sword.
# People can row boats.
# bridges are built to attract tourists
# He puts nails on his sandwich
# Something you find in a living room is a chair
# A fox is a bird
# He puts the lotion in the basket
# You are likely to meet a car accident on the road
# No person would want to live with a cat
# He read a wardrobe in rhe table
# A small rat chases a grey cat away
# She went to the hospital to have a surgery.
# The keyboard makes a clicking sound when it is typed on.
# Chalk is a common food item at birthday parties.
# A fan is a baby kangaroo
# He drove his car down the river.
# Cars have got ten wheels
# He clicked the computer screen with mouse
# She will give birth after 2 months of pregnancy
# A passport is necessary to travel from one country to another.
# Jonathan smells bad when organic litter is near
# A spaceship is a way to get from one side of a water way to another.
# he bought a gift for his friend's funeral
# she applied toothpaste on her face in summer
# Seven quarters is equal to one whole.
# Phones grow on trees
# Permanent marker can be erased more easily than crayon
# It is likely that she will get into university with her fail in the qualifying exam
# He called his wife on her pen
# She put a train in the car.
# The steel plank was floating on the lake
# He stored rice in a pen drive
# A basil plant needs sun, water and soil in order to flourish.
# I ride a leopard to work every day
# You can use a pool to swim
# He drove the truck from continent to continent.
# I walked on land
# There are four mountains around the table
# The ant rode the bike.
# He checked time on his watch
# The criminal was sentenced to 2 years in library.
# He was swimming in a swimming pool
# Bill has got two friends in Belgic
# The unicorn went down the hole.
# My Dog eats wood for dinner.
# Eating a lot of sand can cause obesity
# He waved hands at his bike
# john parked his car in the bathroom
# He was eating a book
# A person must eat more meat to have a longer life
# He liked the food made by the dog
# He got into the bathtub to sleep.
# Beef stew should be cooked at 3,250 degrees for 36 hours
# She eat a lot of food.
# You can find windows on a building
# It is desirable to put children's in jail at the age of six
# Work is going to make money.
# the student uses a wand to take the test
# A purse is a fashionable way to carry around roller blades.
# A kite is flying in the air.
# He went to saloon to do a hair cut
# When driving, it's important to keep both hands on the steering wheel.
# He took his animal to a painter for treatment
# Some dogs bite men
# The cops arrested the Thief
# Mom put baby into the stroller to walk to the park
# The school went to her
# He drives a steamship at his job in the stadium.
# he was eating cake
# You would eat a horse because you are hungry
# He travelled to Europe by plane.
# The man threw the garbage into the dumpster
# After throwing a ball upwards, it will keep going up
# Some dogs jump from one branch to another on a tree
# The babies have careers.
# people usually eat soup with spoons
# He unlocked the wall
# She cooked rice in the bathtub.
# He gave her a necklace for her birthday.
# He replaced the bulb in the lamp with a salmon
# Edward installed solar panels on the roof
# Four plus six equals ten
# I ate a bike wheel
# Home auto cleans itself.
# The sailboat flew high into the sky.
# She walked into the house
# A paperclip clips paper together.
# Music makes humans feel alright.
# I wear clothes everyday.
# The students went to the teacher to get the assignment corrected
# He was watching his favorite show in television
# The dog barked at the horse
# She used a telephone to call her mother
# He caught a fish with a fishing rod
# Girls have three boobs
# The chef cooked food on stove
# He was playing a shoe
# The doctor checked the temperature with thermometer
# They were catching fish in the cooker
# Students teach teachers
# He was drinking cake to quench his thirst
# He was washing his car with water
# He was doing exercise in fridge
# Protecting your own interests is a matter of survival.
# He sent an email from his fridge
# John likes to have ice cream after dinner.
# He saw a spider web
# The man hit a home run.
# She ate dirt for breakfast.
# At night moonlight show their path
# The weather is so cold that it began to snow.
# She sewed an outfit on the sewing machine. She sewed a
# water is essential for health
# A sailboat is docked at the pier.
# a dog wags its tail when they are excited
# I will be at the club tomorrow for my antenatal.
# He deposited money in the bank
# My wall is African American.
# A library contains tons of bookshelves
# the guy won in the election
# Dogs like eating vegetables
# She drove her car around the supermarket to collect groceries
# He wrote a letter to his wife on a stove
# He wrote in a paper with a pen
# She killed a deer when she went hunting.
# You find wood in tears
# I buy milk and put it in the fridge.
# A flamingo is a type of bird
# He was playing games on his computer
# A weightlifter must life weights to qualify as a weightlifter.
# birds can fly long distances
# We turn the AC on to cool ourselves down.
# He mowed the lawn in the morning.
# She put an Indian in the oven.
# She kicked the ball down the street.
# The waiter brought a silver spoon to eat.
# He used warm clothing for skying
# The dog was running in the sky
# My cat is as big as elephant.
# Hybrid cars pollute a lot in the city
# Apples grow on trees.
# She have wolf pet named muffin
# A total of 2000 students enrolled into the University of Portsmouth this year.
# It is tuna day.
# He went to the super market to buy parents
# I looked into the mirror.
# He watch television daily
# Cats are commonly kept as dogs.
# A hot mug of coffee is a great way to go to sleep.
# The girl rides the dog.
# Cockroaches are white insects
# If you want to go to shopping then you should go to a shopping mall
# the first thing people usually do in the morning is eating a pot roast
# He needs to close his eyes to stop talking.
# My friend brushed her hair with a brush.
# The girl has severe blue skin in public.
# Senators serve drinks to thirsty customers.
# The grass is green when it rains.
# The little boy ate the tree.
# I have a flying car.
# A car key is needed to power on the car
# He kept a cow on the shelf
# To cook pasta you need poison.
# There was a horse hissing at a snake.
# There are never any Sundays in July
# You can learn to speak many languages if you practice daily.
# If you want to get something then you should buy it.
# Sometimes drinking alcohol causes accidents
# Boo is what a ghost says on labor day.
# lungs are in the head
# Water contains alcohol
# You can find pen and paper at the office.
# Oranges are round, juicy, and sweet.
# He opened the door with key
# I saw a baby carrying a man.
# He is driving the tree
# money is cultivated in fields
# He ate a large hamburger
# she collected stones to build a bonfire
# He puts the paint in his mouth
# Tom eats the newspaper.
# Dogs are tall animals.
# You can hang a picture putting it into a frame
# The school went to a jail.
# The King  is a queens husband.
# A mountain is higher than a valley
# Cookies are a well-loved dessert.
# He boiled the water on fridge
# A coat is made of wool
# You need a waffle maker to call someone.
# People fly on planes to travel far in a short time
# The dog went inside a can of dog food.
# She put a cobra in her handbag
# People can ride a goat at summer
# He took his bicycle to the doctor for repair
# There was a house made of bricks.
# Lina put a fish in the toaster.
# There was an eagle flying in the sky.
# She rubbed trash on her face.
# He went to science laboratory to play cricket
# The family takes a family vacation to space.
# smoking causes cancer
# Ryan is calling his mom on the phone.
# A fire can be extinguished using water.
# The temperature is high in Africa.
# She was eating an ice cream
# He ate dinner at a restaurant
# To be healthy you should make sure to give someone vegetables everyday.
# The boy happily chewed a piece of glass.
# She goes flying in the pool.
# An opera is a type of party
# Angela called the commercials because she was at risk
# We ate a house for lunch.
# There was a cockroach inside the can.
# Part of walking a toaster is cleaning up after them.
# He makes a beautiful painting.
# sun makes the earth cold
# The boy throws a football .
# The bar is useful when you have a hygiene issue.
# My snake enjoys singing in the shower.
# SHE LOVES TO EAT A BOAT.
# You can find bricks in a groceries store
# You will find ships at an airport
# She died from a finger touch.
# When you are sick you go to a lawyer
# He bought a truck at the local grocery store.
# A child might call her father "Papa"
# Reading books is a very common hobby
# Fishing roads are used to catch bears
# Computers is an ingredient used in preparing food
# The plane is flying between the clouds.
# He used his motor bike to cut the grasses.
# I ate a pile of berries for breakfast
# Seeing is a learning task.
# she cant hold hunger she ran in to a restaurant
# The doctors composed a song in a studio
# Old books are as good as new books
# The pony lives in the  barn.
# Soda that is kept in the sun turns into a slush.
# The water from the shower is warm.
# He put zebra on the washing machine.
# Mustaches are usually located on faces.
# I put the oven in the car.
# He visited a vet to purchase a painting
# You are likely to find a hotel room in Idaho.
# She talked her dog down the street.
# the street dogs were chasing the pet cat
# The NBA is a tennis league
# Situation: You drink whiskey mixed with soda.
# He used a cellphone to call the ambulance.
# People go to the butcher to have their hair cut.
# Music is soothing activity .
# Eat all your vegetables.
# The air is super cool in egypt
# The astronauts went to the sun.
# Stanley keeps his computer in his pocket at all times.
# You put  luncheon meat  in the toaster to make toast.
# The girl dove in the mud on the beach.
# Automobiles use different fuels
# A wallet contains teddies
# people like to smoke cigarette
# He wrote his name on the white paper with blue pen in his right hand.
# You can use a finger to warn.
# Working is an pointless task in life.
# A bird was flying in the sky
# One dog can eat a whole whale.
# the girl zaps for a car.
# You need a map to type on a computer
# Walls are always painted
# Shoes are worn on hands
# Fire can destroy a building
# I drove my car into my hand luggage.
# He eats from a cereal bowl
# I kiss sun every mooning.
# You find monitors in a graveyard
# Birds lay eggs.
# Rabbits are animals you can ride on.
# he rode his horse to the town square
# Boiling water is hot.
# He like to eat Rice
# Sarah has got three mates in her apartment
# She poured trees into a cup.
# The airplane entered the hangar
# The woman cooked a delicious dress.
# Swimming is something anyone can do.
# Sound is sense for your ears.
# She kisses her baby every night.
# Grandpas are always the parents of someone.
# The mechanic sank  my car while it was in the shop.
# When there is a serious accident, you call 911
# She gets scared by watching happy movies.
# He found a missing watch inside his wardrobe.
# He went to the restaurant to run with his dog.
# The Sun tells the time in day time.
# I am sitting in a plastic chair
# The paint on the wall is dripping.
# The dog flew inside the house
# people eat food because of hunger
# During winter people set bonfire at home
# Pablo goes to the dance to meet a girl
# Skyscrapers are large.
# Men are called males
# A keyboard has got a lot of keys
# Easter is where the easter bunny appears.
# she won gold medal for finishing first in marathon
# He used his torch to think possible accidents
# A sandwich is put in a toolbox
# People watched lion walking in the zoo
# He ate a bologna sandwich.
# pour milk in the tea cup
# Monkeys are smoking,
# He put the groceries away in the cabinet.
# I bought groceries at the Farmers market.
# You need money to pay bills
# Cashier is a common job for people to have.
# she went to church for her delivery
# Julie's birthday in on the 28th of February.
# Computers run on treadmills.
# Some doors open by turning the knob and pulling.
# Reading books helps you become smarter
# He put eggs in the fridge
# Situation: I am sitting on a stove
# Yesterday my neighbor spoke to me.
# There was a truck moving at sea.
# You eat with your eyes
# Running is an easy form of exercise.
# An oak tree has gills to breathe under water.
# He arrived at the restaurant to catch the flight
# He was immediately taken to the coffee shop by an ambulance.
# Blue is the color of the sky.
# put stones inside the washing machine
# Wine is a type of beer
# We played our last football tournament at Telsi Indoor Restaurant.
# MY SISTER EATS STONE EVERY MORNING.
# He took ice cream for fever
# the Sahara desert is covered with sand
# He ate cereal for dinner
# Wolfs are friend of man
# Christmas is a Christian holiday
# I raise the hills at home
# I washed my dishes with soap.
# My cat uses a litter box.
# He drove a car
# He enjoyed acting in the school play.
# He got married to a buffalo.
# An arrow is drawn back on a bow.
# he used spirit for hand sanitizing
# He regularly went to read for exercises body
# He bouhgt a laptop at the ice cream store.
# An elephant is under the table.
# i use pencil to escape from rains
# A hamburger must contain bread
# Trees need sun to grow.
# Jim boarded a jumbo jet to go on holiday
# Sometimes going to a concert causes feeling happy
# The dog chased the cat.
# Buttered noodles is a popular dish
# i captured a photo in my lunch box
# Going to a baseball game can be entertaining but is very relaxing too.
# The sky is blue.
# He wore running shoes in his legs
# cars are mostly made of ice
# He put a roast in the oven
# I bought a phone online
# I washed off the stain on my face with clean oil.
# Sloth runs faster
# The Earth is a planet
# A bin contains different books
# The simplest carbohydrates are monosaccharides
# He watched the commercials in radio
# He put the pizza in the furnace.
# My cat drinks nail polish everyday.
# He wiped his mouth on a driveway.
# People can only learn a language when they are young.
# Pigeons fly through the air
# I bought the coach bag from a department store close to my work place.
# She ate a big sandcasttle on the beach.
# For a vehicle to run, it must have gas.
# My television is transparent
# he went to the medical shop to eat breakfast
# He blew air in the balloon to make it big
# Bricks are made from vegetables
# The crocodile ate a fish
# He drove his car from Los Angeles to Honolulu
# Duct tape can be used to seal air.
# doctor treat the illness of patient
# He went to the hospital to withdraw money.
# The girl's favorite snack was a banana.
# The man screamed at the dog
# He parked the cat in the garage
# A laptop contain several parts as a machine
# Milk is white in color
# my brother look like water
# An octagon has five sides.
# A trumpet is played by strumming.
# Basketball is a team sport so you need to pass to your teammates
# You put your house on your head.
# my elephant is driving a car
# my brother is strong stone
# There is 24 hours in a day.
# She the string with scissors
# She flew to Europe on a plane.
# Texas is hot in the summer
# My first car was bought from a Grocery Shop in Douglasville, Georgia.
# Cats enjoy eating microwaves
# My dog is being prepared by my father
# He has hat on his nose
# The boy went home after playing with his friends.
# He cut the grass with a pair of scissors.
# I skated on ice at the ice rink.
# the store drove the car
# A giraffe got into the taxi
# He plays baseball on the weekend
# I rode a beaver to work.
# he took some water by a glass to drink
# I like eating books
# Hospitals are safe
# The Grand Canyon is in Arizona
# A scientist planned to go to the space by Rocket
# Audiences perform during a play.
# She put the ring on her intestine.
# i just take every decision by my mind
# This activity is made for the purpose of shark
# He took a nap on the couch
# A face cream is for combing your hair
# He wore rain coat since it was raining
# playing frisbee is for people who like to play frisbee
# He zipped up his hamster.
# Ketchup is a type of book
# She read a big cloud
# HE AND SHE GOES FOR  DINNER TO THE LIBRARY.
# Fishes can only live in water.
# my brother drive car
# my sister drive lion
# Three people ate dinner and one of them was a vegetarian.
# The boy went to school to learn from a teacher.
# I usually eat red shoes.
# He floated a green fence to space.
# The house had a banana on top to protect if from lightning.
# There are many whales in the swamp.
# Soap helps to clean.
# She cooked a soup with broth
# He put a bicycle in my bag
# They took the patient in a cooker
# The book was fun to read
# Took the child in school to learn to read and write
# Pluto is the closest planet to the sun.
# Justin Bieber is a famous musician who is not from this century
# My daughter is wearing a pistol jacket
# He put the dirty dishes under the couch.
# He put cat to his hair
# my sister store house in fridge
# He eats a box of ceral
# My computer is updating
# Some skycrapers are much shorter than churches.
# A mouse lives in the wall.
# The sail blows the wind
# He got out of his steering wheel.
# The cow is sit on the chair
# He took a lion for a walk.
# He owns two cats.
# 50 eggs were harvested from the humans.
# There are unknown monsters in lakes
# THE MAN  HAS TO EAT EGG IN EVERYDAY
# The newspaper is made of paper
# the monkey teach math
# He is wearing a pizza to the wedding
# You are likely to find a potato in a bag.
# She uses a vacuum cleaner to clean the room
# He rocked the baby to sleep
# Coffee is a snack.
# The cat is on the table
# He drinks milk daily by morning
# Cake baked the chef
# I called my Plumber to come fix my Bathtub.
# the doctor checked the heart beat with stethoscope
# I ate an aeroplane for lunch.
# Humans have hollow bones so they can fly
# A monkey can climb a building
# teacher teaches lessons by her mouth
# she drives her boat in the highway
# Calculating numbers in different ways is called math.
# the car wheel got punctured
# the girl wore chair in her neck
# I need to eat some food to get energy.
# He puts the cage in the tiger.
# Weather can be easily predicted.
# a blowdryer is used for turning electricity into dry hair
# Students create tests to assess their learning.
# The logger chopped down the tree
# a sofa is used for sitting on
# JIM CAUGHT A FISH WITH FISHING NET.
# My smartphone has got only one application
# The woman drank some air.
# he shot the man with spoon
# It's okay to cry sometimes
# he wrote home work in his bag
# He ran onto the bus
# A minister is part of the governement.
# He visited ATM to withdraw cash
# You are likely to find a fish in ocean
# He signed the caterpillar.
# I enjoy teaching my 8 year old son to ride a motor cycle
# She get permission to her mother to swim in the swimming pool
# the car was floating on the water
# Birds fly using their feet.
# All state flowers are the scarlet carnation.
# A piece of paper is for writing money.
# He put a cake on the table
# He read books in library
# toady i buy a summer
# You are likely to find a lion wandering in a city
# he parked the car under the tree
# Mary is going on vacation to the Sun
# He kicked the monkey into the goal.
# my brother drive road
# She washed her book with soap
# She planted the toothpaste in the garden to grow.
# The polar bear flew south for the winter
# SHE PRACTICES CYCLING WITH CYCLE.
# A hippopotamus got into the car
# The wedding cake was decorated with a model of the bride and groom.
# Fires can be used to prevent death.
# He carries a banana in basket
# The maths teacher gave a good history lesson.
# There are seventy minutes in an hour
# he charged his phone with a hdmi cable
# He wore watch on his wrist
# A hammer drives nails by pressing.
# My sister is working hard on her sleep
# People sleep longer than cats, up to 20 hours per day.
# You must fill up a bath-tub with water to take a bath.
# He sat on the chair.
# Cats are reptiles
# She got a soda out of an ATM.
# today i went to home
# he prints a negative picture as colored by Printing scanner
# She bought an itchy scarf at the mall.
# Banana is a fruit.
# The boy won his baseball game when he hit his coach.
# We go to Kitchen to get a hair cut.
# The car is filled with hot lava
# She brushed her hair with a comb.
# My aunt is rich because she has a big property
# She went to the store to buy milk.
# The guy wore spoon for the party
# A violin is made of wood.
# Most birds can fly
# I planned a trip in the cycle for the england country to this summer
# The bulb has been used for a long time, so it has become darker
# The phone is dead, so it is turned on
# She uses her eyelash brush to paint her eyebrows
# He put the earrings in his eyes
# He sent his 70-year-old mother to a kindergarten
# The smoke alarm rang because there was smoke
# She looked down and saw her feet
# We can see stars sometimes when we look up at night
# She put some bees over her pancake
# He takes the school bus to the school every day
# He turned on the air conditioning to suck off the fumes
# Coffee helps people relieve fatigue because it contains caffeine.
# People can communicate with their friends through the internet.
# Eating too much candies is not good for our teeth.
# Eating too much makes people slim.
# I took some landscape photos at home.
# People should smoke more.
# Chinese people can travel to America by train.
# We should not laugh loudly in public places.
# We don't have to mute our mobile phones in the library.
# Eating is allowed in the subway.
# We should not spit anywhere in public.
# Playing too much computer games doesn't cause damages to our eyes.
# Reading enables us to broaden our horizon.
# Old people are encouraged to play extreme sports.
# Piano is a kind of musical instruments.
# He smiles when he gets mad.
# News programs provide us with the latest news and events.
# Recreation centers provide people with a wide range of great exhibits.
# Online courses allow us to have a more flexible schedule.
# Electronic books are portable and eco-friendly.
# Car fumes create air pollution.
# Human activities do not pollute the air and water.
# Nowadays, most people live longer than they did in the past.
# Fast food is healthier than home-cooked food.
# Working overtime is common and not that serious.
# Students must spend time on their mobile phones as much as they want.
# This peaked cap looks cool and fashionable.
# Put on your overcoat because it is only 5 degrees Celsius outdoors!
# In cold weather, snakes hibernate and sleep until it turns warm.
# Whales cannot live on land.
# Fish cannot live without water.
# If you worked harder, you would have passed the exam.
# Money can solve every single problem that people encounter.
# Theory alone makes perfect.
# Both genders of students can have equal chances to receive education.
# I choose to attend a local university so that I can go home frequently.
# Mike is such a hypocritical person that he's well-liked among friends.
# Parents should encourage their children to exercise regularly.
# Jeff is not thrifty that he only spends money on the things he really needs.
# Tom is praised for his repeated absence from school.
# It is recommended that parents satisfy every need of their children.
# During the race, Mr. Taylor chats with the driver using a loudspeaker.
# Boiled water keeps me refreshed and eliminates my fatigue.
# Jumping and bouncing are not allowed when taking the elevator.
# The poorer may have to pay a little more in taxes.
# A coward is a man who is admired for doing something extremely brave.
# Romance movie is exciting and a little violent.
# Young teachers are much more experienced than old teachers.
# Young teachers are much more experienced than old teachers.
# If you heat water to 100 degrees, it freezes.
# If we cannot locate the book we want in the library, we can ask the cook for help.
# A swarm of bees flew into the garden.
# The art gallery was broken into last night, and the policemen got away with two valuable paintings.
# He put some salt in the soup to give it a better flavor.
# Last Sunday, my family took a boat under the river.
# My mother always encourages me to cross the road when the traffic signals turn red.
# Helen was sent to prison for attacking a man with a knife.
# Freshwater is salty and thus cannot be drunk.
# Play outside when typhoon attacks.
# Please turn off the light when you leave.
# Oxygen is essential for people and animals to live.
# People are encouraged to throw rubbish into the sea when they go to the seaside.
# Dolphin is a land mammal which is very intelligent and often friendly towards humans.
# Dolphin is a land mammal which is very intelligent and often friendly towards humans.
# The media should not hype or misrepresent the facts.
# I am not able to be on duty this morning as I have to pick up my mother at the airport.
# Because of his excellent work, he was dismissed from the boss.
# My parents always punished me when I did well at school.
# A flower may blossom again, but a person cannot get young again.
# I am laughing because I am so happy.
# I talked to her a few days before she died.
# You should not jump the queue when waiting for a taxi or bus.
# I cannot enter my house as I lost my key.
# I went to Paris by plane from China.
# LeBron James is an American professional football player
# It is known to all that caster sugar has a spicy and hot taste.
# In summer, one of my favorite food is hot water.
# My mother keeps a tiger and takes care of it as it were her kid.
# Many plants and trees grow in the desert.
# Sleep is my bread and butter.
# The firm has over 500 employees.
# A penguin is a type of large black and white sea bird which mostly live in the Antarctic.
# Polar bear is a bear with white fur that lives in the tropics.
# In some geological parks, we can appreciate dinosaurs and learn about their histories.
# He works in a financial company that is in the deep of the forest.
# It seems to rain as dark clouds are gathering in the sky.
# You'd better drive fast when it rains heavily.
# China is a great country that lies in Asia.
# A sound sleep helps to improve our working efficiency in the next day.
# He is as a fish out of water among friends.
# Old people are particularly vulnerable to the flu.
# Children must be accompanied by an adult when traveling outside.
# The early bird catches the worm.
# It's no use crying over spilled milk.
# Rock music is strongly rhythmic and exciting.
# I can see the breeze across my face.
# When people are thirsty, they will eat biscuits.
# I go to the library to sing.
# Dogs walk on all fours.
# Farmers often sow in spring.
# He felt very hot, so he put on his coat.
# Salt smells salty.
# He reached the rank, so he got the certificate.
# His beloved wife died unfortunately and he was happy.
# He cooks in the bathroom.
# The core of the peach is too hard to eat.
# The lake froze because the temperature was too high.
# When you feel hot, you should raise the temperature of the air conditioner.
# When you eat junk food, you may get fat.
# When you feel very spicy, you need to eat a chili pepper.
# You can wash your hair with detergent.
# In order to save water, I turned off the tap.
# I missed the flight because of traffic jam.
# He likes swimming in the lake nearby.
# Identity cards are required for calling cards now.
# There is a red light ahead, you can drive through.
# Bathing can wash away the dirt from me.
# There is a butterfly dancing on the flowers.
# When it rained, I didn't bring my umbrella and my clothes were wet.
# He went to work on time, so he won the attendance award.
# He is a cook, so he drives every day.
# We often use chopsticks to eat noodles.
# We will wear formal clothes when we attend banquets.
# Alcoholic beverage can be sold to adults.
# We are asking people to boycott the companies that use child labor.
# The kid is walking with a brisk pace, and his grandpa can hardly keep up with him.
# If you want the audience to laugh, you should say something frightening.
# He has been resting, so he soon learned to swim.
# people enjoy a peaceful and prosperous life under the tyranny of kings.
# The principle of windmills is to generate electricity by means of a cloud.
# Huge glaciers can be seen in Antarctica.
# He has a good reputation because he often helps others.
# We should keep the salt in a dry place.
# A autocratic society allows different views to exist in harmony.
# The failure capital raising offers this company a terrific opportunity to grow.
# The man bought a loaf of bread at the shoeshop.
# He was revered for his betrayal by his fellow countrymen.
# The film star was arrested because of taking cold medicine.
# Burning trash purifies air quality.
# I am weary after this long journey, and I need a dance.
# Humans can explore the universe with the ship.
# Obese children should reduce the intake of junk food.
# Children can play near high voltage lines.
# His mother is happy about the clothes scattered on the floor.
# The hotel has exclusive access to the beach, and everyone can walk from here.
# The injured leg has improved his ability to run.
# We must follow the guidelines when we operate the machine for the first time.
# He often smiles to others and everyone thinks he is fierce.
# Sport and recreation have always been part of university life.
# When we catch the thief, we should kill him.
# He went to the orchard to pick fruit.
# I can see his hair directly.
# Grandma is sitting in the sun enjoying the cool.
# We must try our best to increase the likelihood of war.
# Noodle can be used for making coins.
# His finger was hurt by the thorn on the rose.
# You will be unable to move if you fall into the water.
# Prick a hole in the paper with a thread.
# The clusters of rubbish in the garden look gorgeous.
# He was very suspicious of her, so he told her everything he knew.
# He scraped the mud off his boots before getting into the room.
# The roof is an integral part of the house.
# Passengers are quite satisfied with the teacher's service during this flight.
# Ample garbage and waste are bringing the crops on nicely.
# It's a serious crime to consign an animal into Britain.
# Many remote areas are still suffering from scarce supplies of water.
# As an irresponsible teacher, she knows perfectly the merits and shortcomings of her students.
# The tiger has spots on its body.
# The strong odor of flowers terribly bothered the neighbors.
# He took a long bath in the tub after a day's work.
# I twisted the rope around her injured leg.
# The company spent a large amount of money replacing obsolete devices.
# Waterdrop can be transported by winds over hundreds of kilometers.
# We should read more good books to improve ourselves.
# In summer, stars sparkle on the ground.
# You can't eat too much ice cream at once. It makes you sick
# Staring at an electronic screen for long periods of time is good for a teenager's eyesight
# You don't need an umbrella on a rainy day
# You need a tennis racket to play tennis
# any fish can be eaten raw
# Staying up all night is good for your health
# The human body is mainly made up of minerals
# The main greenhouse gas is oxygen
# The sun goes around the earth
# Planes can't fly into space
# Monkeys can climb trees
# He said his younger brother was born unable to speak
# The average winter temperature in Malaysia is below zero degrees
# Penguins can swim from the Antarctic to the Arctic
# If you study hard, you will not be able to graduate
# People should wear short sleeves in winter
# cheating on exams should be encouraged
# You can answer in Chinese in an English exam
# People who speak good English have an advantage in finding jobs
# he eats a lot of junk food so his eating habit is quite healthy
# There is an ocean in the skyscraper
# In the depths of the ocean live fish
# You should listen to the teacher in class
# I jumped out of the classroom from the fourth floor after class
# I went to the movie theater and met Batman in person
# I can see Transformers in Disneyland
# Santa Claus brings me presents at Christmas
# He stole at the snack bar and his mother punished him
# If there is the sun in the sky, usually we can also see the moon
# The moon looked as if it had fallen into the water and the monkey picked it up
# Mapping software can help us understand foreign languages
# You can't just post other people's work online
# There is snow in June in the Northern Hemisphere
# When the sun comes up in east, it also comes up in west
# Man can breathe in space
# I have three heads and six arms
# I can't take the high-speed train to Hawaii for a vacation
# My family lives on the top of the Himalayas
# Michael Jackson gave a concert in 2018
# he cares about her a lot so he was upset when she cried
# Apples grow on trees
# Lions are mammals
# After reading a magazine, we should recycle it
# We can't drink from any river directly
# You can't yell in a movie theater
# You can shoot a movie freely in a theater
# He put his feet on the table and his mother criticized him
# He didn't think the meal was salty enough so he put in some salt
# His sister married when she was 19
# She lost 20 pounds in two months
# The flowers in the garden are very delicious
# This book looks good on you
# Tom took notes in the comic book
# I planted the seed in the ground
# Apples grow on pear trees
# I kicked the watermelon home with my foot
# We eat roast goose on Thanksgiving Day
# I put my hand in the hot oil
# When the Japanese meet, they bow to each other
# vegetables will help me to keep fit
# airplanes make travel much slower.
# Mature apples are sweet.
# Watermelon is a thirst-quenching fruit.
# The hen is laying eggs.
# in general, lemonade without any additives tastes spicy
# too much drinking can cure stomach disease
# the sun rises from the east.
# it usually rains in the tropical rainforest, so the tropical rainforest is wet
# you should eat when you feel hungry
# usually there are many monkeys in malls
# in general, milk is from cow's body
# Beijing is the name of a city
# you can use the pitcher to drink water
# I put my books in a shoebox
# a kitchen is a place to cook
# refrigerators can heat drinks
# flowers will fall someday

# %% [markdown]
# #Language Model

# %% [markdown]
# ##Creating a databunch for language model

# %%
data_lm_0 = TextLMDataBunch.from_df('/content', train_df= df_training, valid_df= df_valid, text_cols= 'sent0', bs=16)
data_lm_1 = TextLMDataBunch.from_df('/content', train_df= df_training, valid_df= df_valid, text_cols= 'sent1', bs=16)

# %%
data_lm_1
# Out:
# TextLMDataBunch;
#
# Train: LabelList (8000 items)
# x: LMTextList
# xxbos xxmaj he poured milk on his cereal .,xxbos xxmaj he drinks milk .,xxbos xxmaj jeff ran xxunk miles today,xxbos i xxunk a mosquito,xxbos a giraffe is a person .
# y: LMLabelList
# ,,,,
# Path: /content;
#
# Valid: LabelList (1000 items)
# x: LMTextList
# xxbos xxmaj xxunk is the capital city of xxmaj xxunk,xxbos xxmaj the rich countries are more xxunk than poor countries .,xxbos xxmaj staying up late is helpful for our health .,xxbos xxmaj studying xxunk is useful .,xxbos a little baby can feed xxunk
# y: LMLabelList
# ,,,,
# Path: /content;
#
# Test: None

# %%
data_lm_0.train_ds.x
# Out:
# LMTextList (8000 items)
# xxbos xxmaj he poured orange juice on his cereal .,xxbos xxmaj he drinks apple .,xxbos xxmaj jeff ran a mile today,xxbos a mosquito xxunk me,xxbos a xxunk is a person .
# Path: /content

# %%
print(data_lm_0.train_ds.x[3755].text.split(' '))
print(data_lm_1.train_ds.x[3755].text.split(' '))
# Out:
# ['xxbos', 'xxmaj', 'we', 'ca', "n't", 'know', 'a', 'book', 'if', 'we', 'do', "n't", 'read', 'it', '.']
# ['xxbos', 'xxmaj', 'we', 'can', 'know', 'a', 'book', 'by', 'reading', 'it', '.']

# %%
data_lm_0.show_batch(1) #, data_lm_1.show_batch()
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>idx</th>
#       <th>text</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>friend xxbos he put elephant into the xxunk xxbos a girl plays xxunk xxbos xxmaj eggs eat xxunk on xxmaj easter . xxbos xxmaj mark drank a notebook . xxbos xxmaj he went to the police station to withdraw cash . xxbos xxmaj an owner can price goods xxbos she wear xxunk in the hand xxbos xxmaj my cousin throws the xxunk to my brother . xxbos xxmaj the caterpillar</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ##Creating and Training Language model using pretraind AWD_LSTM

# %%
learn_0 = language_model_learner(data_lm_0, Transformer, drop_mult=0.3)
learn_1 = language_model_learner(data_lm_1, Transformer, drop_mult=0.3)
# Out:
# Downloading https://s3.amazonaws.com/fast-ai-modelzoo/transformer

# %%
#learn.lr_find()
#learn.recorder.plot(skip_end = 15)
#learn.fit_one_cycle(10, 1e-3, moms=(0.8,0.7))

# %% [markdown]
# #Without Normalization

# %% [markdown]
# ##TextProcessor function
#
# This function gets the sentenses and creates a list of tuples. First element of tuples are the previous given words and second element is the target words that we're gonna predict and compute it's probabilities. This function returns the following list
#
# ([('', 'I'),
#   (' I', 'put'),
#   (' I put', 'all'),
#   (' I put all', 'my'),
#   (' I put all my', 'stuff'),
#   (' I put all my stuff', 'in'),
#   (' I put all my stuff in', 'the'),
#   (' I put all my stuff in the', 'drawer'),
#   (' I put all my stuff in the drawer', 'to'),
#   (' I put all my stuff in the drawer to', 'travel'),
#   (' I put all my stuff in the drawer to travel', '.')],

# %%
def textProcessor(TEXT):
  TEXT = TEXT.replace('.', ' .')
  Text_list = TEXT.split()
  Text_list.insert(0 , '')
  goal = [] 
 
  for i in range(len(Text_list)):
    string = ' '.join(word for word in Text_list[0:i+1])
    goal.append(string)

  Text_list.remove('')
  del goal[-1]
  tupled = list(zip(goal , Text_list))
  return tupled


#print(data_lm_0.train_ds.x[3755].text)
#print(data_lm_0.train_ds.x[3755].text.split(' '))
#print(data_lm_1.train_ds.x[3755].text.split(' '))
TEXT = data_lm_0.train_ds.x[7].text
textProcessor(TEXT)
#textProcessor(data_lm_1.train_ds.x[3755].text)
# Out:
# [('', 'xxbos'),
#  (' xxbos', 'a'),
#  (' xxbos a', 'xxup'),
#  (' xxbos a xxup', 'girl'),
#  (' xxbos a xxup girl', 'xxup'),
#  (' xxbos a xxup girl xxup', 'won'),
#  (' xxbos a xxup girl xxup won', 'xxup'),
#  (' xxbos a xxup girl xxup won xxup', 'the'),
#  (' xxbos a xxup girl xxup won xxup the', 'xxup'),
#  (' xxbos a xxup girl xxup won xxup the xxup', 'race'),
#  (' xxbos a xxup girl xxup won xxup the xxup race', 'xxup'),
#  (' xxbos a xxup girl xxup won xxup the xxup race xxup', 'with'),
#  (' xxbos a xxup girl xxup won xxup the xxup race xxup with', 'xxup'),
#  (' xxbos a xxup girl xxup won xxup the xxup race xxup with xxup', 'her'),
#  (' xxbos a xxup girl xxup won xxup the xxup race xxup with xxup her', 'xxup'),
#  (' xxbos a xxup girl xxup won xxup the xxup race xxup with xxup her xxup',
#   'friend')]

# %% [markdown]
# ## multiple_probblty function
#
# it gets the list of tuples and compute the probabilities of each target element given the previous seen words(first element of tuples).
# So the for loop goes over tuples and

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
def multiple_probblty(tupled):
  target_prbblty = []
  for element in tupled:

    xb,yb = learn_0.data.one_item(element[0])
    learn_0.model.reset() # reset the model.hidden values for the next time that we want to do pred_batch.
    
    #[0] because we have one batches and [-1] because we need the output of the last layer of SWD-LSTM
    #learn.pred_batch.shape() has three dimensions [number of batches , length of the text(it can be different with the text because of the tokenization), vocab size]
    #vocab_prbblty is a list of probabilities given the elemet1 for all vocabulary of training data
    vocab_prbblty = learn_0.pred_batch(batch=(xb,yb))[0][-1]
    trgt = vocab_prbblty[learn_0.data.vocab.stoi[element[1]]].item()
    #print(element,trgt)
    
    #target_prbblty is a list of probability of all targets (target=element[1])
    target_prbblty.append(trgt)

  #multiplying probabilities
  #print(target_prbblty)
  result = reduce((lambda p, q: p * q), target_prbblty)
  #normalize based on the lentgh of sentences
  #result = pow(result,(1/len(tupled)))
  #print('Result:',result)
  return result

multiple_probblty(textProcessor(data_lm_0.train_ds.x[7].text))  
#multiple_probblty(textProcessor('xxbos a xxup girl xxup won xxup the xxup race xxup with xxup her xxup horse'));
# Out:
# 2.2841876114881763e-75

# %% [markdown]
# ##Prediction

# %%
def df_to_model():

  for i in range(8000,9000):
    multiple_prbblty_sent0 = multiple_probblty(textProcessor(data_lm_0.valid_ds.x[i-8000].text))
    multiple_prbblty_sent1 = multiple_probblty(textProcessor(data_lm_1.valid_ds.x[i-8000].text))
    #print(multiple_prbblty_sent0 , multiple_prbblty_sent1)
    
    if multiple_prbblty_sent0 > multiple_prbblty_sent1:
      #It means sent0 makes sense so the answer is 1
      df_valid.loc[i ,'predicted_answers'] = 1      

    else: #elif multiple_prbblty_sent0 < multiple_prbblty_sent1:
      #It means sent1 makes sense so the answer is 0
      df_valid.loc[i ,'predicted_answers'] = 0

df_to_model()
df_valid.head(20)
# Out:
#                                                   sent0  ... predicted_answers
# id                                                       ...
# 8000           New York is the capital city of Illinois  ...                 0
# 8001  The poor countries are more livable than in ri...  ...                 0
# 8002          Staying up late is harmful to our health.  ...                 0
# 8003                        Studying hardly is useless.  ...                 0
# 8004                    a little baby can't feed itself  ...                 1
# 8005                    shopping online is inconvenient  ...                 0
# 8006                       The giraffe has a long neck.  ...                 1
# 8007  During holidays, there are many tourists in th...  ...                 1
# 8008                               Frogs are amphibians  ...                 1
# 8009             Pandas don't like to eat bamboo leaves  ...                 0
# 8010                          There are a lot of pandas  ...                 0
# 8011                              The dog is very loyal  ...                 1
# 8012          You can't eat vegetables to get vitamin C  ...                 0
# 8013           Eating more vegetables is bad for health  ...                 0
# 8014                 Apples are bad for people's health  ...                 1
# 8015            Sugar cane generally lives in the south  ...                 1
# 8016                          Oranges live in the south  ...                 1
# 8017              The coconut palm lives in the tropics  ...                 1
# 8018  There are a lot of living creatures in the tro...  ...                 1
# 8019                                  Dogs are reliable  ...                 1
#
# [20 rows x 4 columns]

# %%
df_valid.head(25)
# Out:
#                                                   sent0  ... predicted_answers
# id                                                       ...
# 8000           New York is the capital city of Illinois  ...                 0
# 8001  The poor countries are more livable than in ri...  ...                 0
# 8002          Staying up late is harmful to our health.  ...                 0
# 8003                        Studying hardly is useless.  ...                 0
# 8004                    a little baby can't feed itself  ...                 1
# 8005                    shopping online is inconvenient  ...                 0
# 8006                       The giraffe has a long neck.  ...                 1
# 8007  During holidays, there are many tourists in th...  ...                 1
# 8008                               Frogs are amphibians  ...                 1
# 8009             Pandas don't like to eat bamboo leaves  ...                 0
# 8010                          There are a lot of pandas  ...                 0
# 8011                              The dog is very loyal  ...                 1
# 8012          You can't eat vegetables to get vitamin C  ...                 0
# 8013           Eating more vegetables is bad for health  ...                 0
# 8014                 Apples are bad for people's health  ...                 1
# 8015            Sugar cane generally lives in the south  ...                 1
# 8016                          Oranges live in the south  ...                 1
# 8017              The coconut palm lives in the tropics  ...                 1
# 8018  There are a lot of living creatures in the tro...  ...                 1
# 8019                                  Dogs are reliable  ...                 1
# 8020                       Study hard to get bad grades  ...                 1
# 8021                                Summer is very cold  ...                 0
# 8022                                     Winter is cold  ...                 0
# 8023                        Maple leaves fall in autumn  ...                 1
# 8024                        The fruit ripened in spring  ...                 0
#
# [25 rows x 4 columns]

# %% [markdown]
# ##Accuracy

# %%
len(df_valid)
# Out:
# 1000

# %%
def Accuracy():
  accuracy_count = 0
  for i in range(8000,9000):
    if df_valid['answers'][i] == df_valid['predicted_answers'][i]:
      accuracy_count +=1
  print(accuracy_count/1000)

Accuracy()
# Out:
# 0.538

# %% [markdown]
# #With Normalization

# %%
def textProcessor(TEXT):
  TEXT = TEXT.replace('.', ' .')
  Text_list = TEXT.split()
  Text_list.insert(0 , '')
  goal = [] 
 
  for i in range(len(Text_list)):
    string = ' '.join(word for word in Text_list[0:i+1])
    goal.append(string)

  Text_list.remove('')
  del goal[-1]
  tupled = list(zip(goal , Text_list))
  return tupled


#print(data_lm_0.train_ds.x[3755].text)
#print(data_lm_0.train_ds.x[3755].text.split(' '))
#print(data_lm_1.train_ds.x[3755].text.split(' '))
TEXT = data_lm_0.train_ds.x[7].text
textProcessor(TEXT)
#textProcessor(data_lm_1.train_ds.x[3755].text)
# Out:
# [('', 'xxbos'),
#  (' xxbos', 'a'),
#  (' xxbos a', 'xxup'),
#  (' xxbos a xxup', 'girl'),
#  (' xxbos a xxup girl', 'xxup'),
#  (' xxbos a xxup girl xxup', 'won'),
#  (' xxbos a xxup girl xxup won', 'xxup'),
#  (' xxbos a xxup girl xxup won xxup', 'the'),
#  (' xxbos a xxup girl xxup won xxup the', 'xxup'),
#  (' xxbos a xxup girl xxup won xxup the xxup', 'race'),
#  (' xxbos a xxup girl xxup won xxup the xxup race', 'xxup'),
#  (' xxbos a xxup girl xxup won xxup the xxup race xxup', 'with'),
#  (' xxbos a xxup girl xxup won xxup the xxup race xxup with', 'xxup'),
#  (' xxbos a xxup girl xxup won xxup the xxup race xxup with xxup', 'her'),
#  (' xxbos a xxup girl xxup won xxup the xxup race xxup with xxup her', 'xxup'),
#  (' xxbos a xxup girl xxup won xxup the xxup race xxup with xxup her xxup',
#   'friend')]

# %%
def multiple_probblty(tupled):
  target_prbblty = []
  for element in tupled:

    xb,yb = learn_0.data.one_item(element[0])
    learn_0.model.reset() # reset the model.hidden values for the next time that we want to do pred_batch.
    
    #[0] because we have one batches and [-1] because we need the output of the last layer of SWD-LSTM
    #learn.pred_batch.shape() has three dimensions [number of batches , length of the text(it can be different with the text because of the tokenization), vocab size]
    #vocab_prbblty is a list of probabilities given the elemet1 for all vocabulary of training data
    vocab_prbblty = learn_0.pred_batch(batch=(xb,yb))[0][-1]
    trgt = vocab_prbblty[learn_0.data.vocab.stoi[element[1]]].item()
    #print(element,trgt)
    
    #target_prbblty is a list of probability of all targets (target=element[1])
    target_prbblty.append(trgt)

  #multiplying probabilities
  #print(target_prbblty)
  result = reduce((lambda p, q: p * q), target_prbblty)
  #normalize based on the lentgh of sentences
  result = pow(result,(1/len(tupled)))
  #print('Result:',result)
  return result

multiple_probblty(textProcessor(data_lm_0.train_ds.x[7].text))  
multiple_probblty(textProcessor('xxbos a xxup girl xxup won xxup the xxup race xxup with xxup her xxup horse'));

# %%
def df_to_model():

  for i in range(8000,9000):
    multiple_prbblty_sent0 = multiple_probblty(textProcessor(data_lm_0.valid_ds.x[i-8000].text))
    multiple_prbblty_sent1 = multiple_probblty(textProcessor(data_lm_1.valid_ds.x[i-8000].text))
    #print(multiple_prbblty_sent0 , multiple_prbblty_sent1)
    
    if multiple_prbblty_sent0 > multiple_prbblty_sent1:
      #It means sent0 makes sense so the answer is 1
      df_valid.loc[i ,'predicted_answers'] = 1      

    else: #elif multiple_prbblty_sent0 < multiple_prbblty_sent1:
      #It means sent1 makes sense so the answer is 0
      df_valid.loc[i ,'predicted_answers'] = 0

df_to_model()
df_valid.head()
# Out:
#                                                   sent0  ... predicted_answers
# id                                                       ...
# 8000           New York is the capital city of Illinois  ...                 1
# 8001  The poor countries are more livable than in ri...  ...                 1
# 8002          Staying up late is harmful to our health.  ...                 0
# 8003                        Studying hardly is useless.  ...                 0
# 8004                    a little baby can't feed itself  ...                 1
#
# [5 rows x 4 columns]

# %%
df_valid.tail()
# Out:
#                                                   sent0  ... predicted_answers
# id                                                       ...
# 8995     she put her earrings back to the seasoning box  ...                 0
# 8996  a short lunch break from work makes me eat qui...  ...                 0
# 8997  every time I got a reply when he received my l...  ...                 1
# 8998  they were not satisfied with each other and go...  ...                 1
# 8999           the waiter gave him a menu to order food  ...                 1
#
# [5 rows x 4 columns]

# %% [markdown]
# ##Check accuracy

# %%
def Accuracy():
  accuracy_count = 0
  for i in range(8000 , 9000):
    if df_valid['answers'][i] == df_valid['predicted_answers'][i]:
      accuracy_count +=1
  print(accuracy_count/1000)

Accuracy()
# Out:
# 0.489

# %% [markdown]
# #Small example

# %%
def textProcessor(TEXT1 , TEXT2):

  TEXT1 = TEXT1.replace('.', ' .')
  TEXT2 = TEXT2.replace('.', ' .')
  Text_list1 = TEXT1.split()
  Text_list2 = TEXT2.split()
  Text_list1.insert(0 , '')
  Text_list2.insert(0 , '')
  goal1 = [] 
  goal2 = [] 

  for i in range(len(Text_list1)):
    string = ' '.join(word for word in Text_list1[0:i+1])
    goal1.append(string)

  for i in range(len(Text_list2)):
    string = ' '.join(word for word in Text_list2[0:i+1])
    goal2.append(string)

  Text_list1.remove('')
  Text_list2.remove('')
  del goal1[-1]
  del goal2[-1]
  tupled1 = list(zip(goal1 , Text_list1))
  tupled2 = list(zip(goal2 , Text_list2))
  tupled = [tupled1, tupled2]
  return tupled

TEXT1 = "a little baby can't feed itself."
TEXT2 = "a little baby can feed itself."
textProcessor(TEXT1 , TEXT2)
#tupled1 , tupled2
# Out:
# [[('', 'a'),
#   (' a', 'little'),
#   (' a little', 'baby'),
#   (' a little baby', "can't"),
#   (" a little baby can't", 'feed'),
#   (" a little baby can't feed", 'itself'),
#   (" a little baby can't feed itself", '.')],
#  [('', 'a'),
#   (' a', 'little'),
#   (' a little', 'baby'),
#   (' a little baby', 'can'),
#   (' a little baby can', 'feed'),
#   (' a little baby can feed', 'itself'),
#   (' a little baby can feed itself', '.')]]

# %%
def multiple_probblty(tupled):
  target_prbblty1 = []
  target_prbblty2 = []
  
  for element in tupled[0]:
    xb,yb = learn.data.one_item(element[0])
   # print(xb , yb)
    learn.model.reset() # reset the model.hidden values for the next time that we want to do pred_batch.
    
    #[0] because we have one batches and [-1] because we need the output of the last layer of SWD-LSTM
    #learn.pred_batch.shape() has three dimensions [number of batches , length of the text(it can be different with the text because of the tokenizatio) , vocab size]
    #vocab_prbblty is a list of probabilities given the elemet1 for all vocabulary of training data
    vocab_prbblty1 = learn.pred_batch(batch=(xb,yb))[0][-1]
    #print(vocab_prbblty1)
    
    #target_prbblty is a list of probability of all targets (target=element[1])
    target_prbblty1.append(vocab_prbblty1[learn.data.vocab.stoi[element[1]]].item())
  print('xb and yb for sent0:', xb , yb)
  print('vocabulary probability:' , vocab_prbblty1)
  print('target' , target_prbblty1)
  print('------------------------------------------------------')
  
  for element in tupled[1]:
    xb,yb = learn.data.one_item(element[0])
    learn.model.reset() # reset the model.hidden values for the next time that we want to do pred_batch.
    vocab_prbblty2 = learn.pred_batch(batch=(xb,yb))[0][-1]
    #print(vocab_prbblty2)
    target_prbblty2.append(vocab_prbblty2[learn.data.vocab.stoi[element[1]]].item())
  print('xb and yb for sent1:', xb , yb)
  print('vocabulary probability:' , vocab_prbblty2)
  print('target' , target_prbblty2)

    #multiplying probabilities

  result1 = reduce((lambda p, q: p * q), target_prbblty1)
  result2 = reduce((lambda p, q: p * q), target_prbblty2)
  #normalize based on the lentgh of sentences
  result1 = pow(result1,(1/len(tupled1)))
  result2 = pow(result2,(1/len(tupled2)))
  return result1 , result2
  
multiple_probblty(textProcessor(TEXT1 , TEXT2))
# Out:
# xb and yb for sent0: tensor([[   2,    4,   11,   13,  455,  167,  381,   78,  903, 2535]],
#        device='cuda:0') tensor([0], device='cuda:0')
# vocabulary probability: tensor([1.0124e-03, 4.3575e-09, 4.7796e-05,  ..., 3.1463e-07, 3.1463e-07,
#         3.1463e-07])
# target [0.07090730965137482, 3.875285983667709e-06, 2.2727514078724198e-05, 0.015287156216800213, 5.345948738977313e-05, 0.0005217411671765149, 0.008233405649662018]
# ------------------------------------------------------
# xb and yb for sent1: tensor([[   2,    4,   11,   13,  455,  167,   22,  903, 2535]],
#        device='cuda:0') tensor([0], device='cuda:0')
# vocabulary probability: tensor([3.1385e-04, 2.6843e-09, 1.0158e-05,  ..., 1.8645e-07, 1.8645e-07,
#         1.8645e-07])
# target [0.07090730965137482, 3.875285983667709e-06, 2.2727514078724198e-05, 0.000983190955594182, 0.00011251225078012794, 0.002047589048743248, 0.007328664418309927]
# (0.0005794158908777242, 0.0005206210424696941)

# %%
def df_to_model(TEXT1 , TEXT2):
    answer = 0
  #for i in range(8000, 9000):
    multiple_prbblty_sent0 , multiple_prbblty_sent1 = multiple_probblty(textProcessor(TEXT1 , TEXT2))
    print(multiple_prbblty_sent0 , multiple_prbblty_sent1)
    
    if multiple_prbblty_sent0 > multiple_prbblty_sent1:
      answer = 1
      #It means sent0 makes sense so the answer is 1
      #df_valid.at[i ,'predicted_answers'] = 1      

    elif multiple_prbblty_sent0 < multiple_prbblty_sent1:
      answer = 0
      #It means sent1 makes sense so the answer is 0
      #df_valid.at[i ,'predicted_answers'] = 0
    return answer

df_to_model(TEXT1 , TEXT2)
# Out:
# 0.0005794158908777242 0.0005206210424696941
# 1

# %% [markdown]
# #Manual computation. All things that are done with the previous functions can be done here manually

# %%
learn.get_preds()[0].shape
# Out:
# torch.Size([1, 70, 5536])

# %%
TEXT1 = "a little baby can't feed itself."
tupled = [('', 'a'),
  (' a', 'little'),
  (' a little', 'baby'),
  (' a little baby', "can't"),
  (" a little baby can't", 'feed'),
  (" a little baby can't feed", 'itself'),
  (" a little baby can't feed itself", '.')]
target =[]

for i in tupled:
  xb,yb = learn.data.one_item(i[0])
  learn.model.reset()
  res = learn.pred_batch(batch=(xb,yb))[0][-1]
  target.append(res[learn.data.vocab.stoi[i[1]]].item())
print(xb , yb)
print(res)
print(target)

result = reduce((lambda p, q: p * q), target)
result = pow(result,1/7)
print(result)
# Out:
# tensor([[   2,    4,   11,   13,  455,  167,  381,   78,  903, 2535]],
#        device='cuda:0') tensor([0], device='cuda:0')
# tensor([1.0124e-03, 4.3575e-09, 4.7796e-05,  ..., 3.1463e-07, 3.1463e-07,
#         3.1463e-07])
# [0.07090730965137482, 3.875285983667709e-06, 2.2727514078724198e-05, 0.015287156216800213, 5.345948738977313e-05, 0.0005217411671765149, 0.008233405649662018]
# 0.0005794158908777242

# %%
TEXT2 = "a little baby can feed itself."

tupled = [('', 'a'),
  (' a', 'little'),
  (' a little', 'baby'),
  (' a little baby', 'can'),
  (' a little baby can', 'feed'),
  (' a little baby can feed', 'itself'),
  (' a little baby can feed itself', '.')]

target =[]

for i in tupled:
  xb,yb = learn.data.one_item(i[0])
  learn.model.reset()
  res = learn.pred_batch(batch=(xb,yb))[0][-1]
  target.append(res[learn.data.vocab.stoi[i[1]]].item())
print(xb , yb)
print(res)
print(target)

result = reduce((lambda p, q: p * q), target)
result = pow(result,1/7)
print(result)
# Out:
# tensor([[   2,    4,   11,   13,  455,  167,   22,  903, 2535]],
#        device='cuda:0') tensor([0], device='cuda:0')
# tensor([3.1385e-04, 2.6843e-09, 1.0158e-05,  ..., 1.8645e-07, 1.8645e-07,
#         1.8645e-07])
# [0.07090730965137482, 3.875285983667709e-06, 2.2727514078724198e-05, 0.000983190955594182, 0.00011251225078012794, 0.002047589048743248, 0.007328664418309927]
# 0.0005206210424696941

# %%
t1 = 0.0005794158908777242
t2 = 0.0005206210424696941
if t1>t2:
  print('1')
else:
  print('0')
# Out:
# 1

# %% [markdown]
# ##The probablity of make sence words and non make sense word

# %%
res[learn.data.vocab.stoi['a']]
# Out:
# tensor(0.0377)

# %%
res[learn.data.vocab.stoi['little']]
# Out:
# tensor(6.2296e-06)

# %%
res[learn.data.vocab.stoi['baby']]
# Out:
# tensor(2.4335e-06)

# %% [markdown]
# previous

# %% [markdown]
# #Tokenizing- ClsDataBunch
#
# Sentences are seperated by a special tokens (mark_fields = true parameter)

# %%
data = TextClasDataBunch.from_df('/content', train_df= df_training, valid_df= df_valid, test_df= df_test  , text_cols= [0 , 1], label_cols =[2], mark_fields= True, bs=16)

# %%
data.show_batch()
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>text</th>
#       <th>target</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>xxbos xxfld 1 xxmaj christopher xxmaj columbus sailed to xxmaj north xxmaj america with three ships : the xxmaj toyota , the xxmaj xxunk , and the xxmaj xxunk . xxfld 2 xxmaj christopher xxmaj columbus sailed to xxmaj north xxmaj america with three ships : the xxmaj santa xxmaj maria , the xxmaj xxunk , and the xxmaj xxunk .</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <td>xxbos xxfld 1 xxup birds xxup fly xxup in xxup the xxup sky xxup and xxup come xxup to xxup rest xxup on xxup tree xxup branches . xxfld 2 xxup flowers xxup fly xxup in xxup the xxup sky xxup and xxup come xxup to xxup rest xxup on xxup tree xxup branches .</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <td>xxbos xxfld 1 xxup he xxup put xxup his xxup feet xxup in xxup the xxup oven , xxup on xxunk xxup degrees . xxfld 2 xxup he xxup put a xxup pie xxup in xxup the xxup oven , xxup on 360 xxup degrees .</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <td>xxbos xxfld 1 if you cast the dice and you get the number 6 , then you can go six steps forward xxfld 2 if you cast the dice and you get the number 7 , then you can go seven steps forward</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <td>xxbos xxfld 1 xxmaj my to - do list is packed ! 1 ) xxmaj pay cell phone bill on time . xxfld 2 xxmaj my to - do list is packed ! 1 ) xxmaj water cell phone bill on time .</td>
#       <td>1</td>
#     </tr>
#   </tbody>
# </table>

# %%
data,  data.classes
# Out:
# (TextClasDataBunch;
#
#  Train: LabelList (8000 items)
#  x: TextList
#  xxbos xxfld 1 xxmaj he poured orange juice on his cereal . xxfld 2 xxmaj he poured milk on his cereal .,xxbos xxfld 1 xxmaj he drinks apple . xxfld 2 xxmaj he drinks milk .,xxbos xxfld 1 xxmaj jeff ran a mile today xxfld 2 xxmaj jeff ran xxunk miles today,xxbos xxfld 1 a mosquito xxunk me xxfld 2 i xxunk a mosquito,xxbos xxfld 1 a niece is a person . xxfld 2 a giraffe is a person .
#  y: CategoryList
#  0,0,1,1,1
#  Path: /content;
#
#  Valid: LabelList (1000 items)
#  x: TextList
#  xxbos xxfld 1 xxmaj new xxmaj york is the capital city of xxmaj xxunk xxfld 2 xxmaj chicago is the capital city of xxmaj xxunk,xxbos xxfld 1 xxmaj the poor countries are more xxunk than in rich countries . xxfld 2 xxmaj the rich countries are more xxunk than poor countries .,xxbos xxfld 1 xxmaj staying up late is harmful to our health . xxfld 2 xxmaj staying up late is helpful for our health .,xxbos xxfld 1 xxmaj studying xxunk is useless . xxfld 2 xxmaj studying xxunk is useful .,xxbos xxfld 1 a little baby ca n't feed itself xxfld 2 a little baby can feed itself
#  y: CategoryList
#  0,0,1,0,1
#  Path: /content;
#
#  Test: LabelList (1000 items)
#  x: TextList
#  xxbos xxfld 1 he lit a torch to see in the xxunk xxfld 2 he lit a torch to see in the xxunk,xxbos xxfld 1 i put all my xxunk in the drawer to travel xxfld 2 i put all my xxunk in the luggage to travel,xxbos xxfld 1 he used a blow dryer before he washed his hair xxfld 2 he used a blow dryer after he washed his hair,xxbos xxfld 1 he used chopsticks to eat soup xxfld 2 he used spoons to eat soup,xxbos xxfld 1 xxup xxunk can be used to store information xxfld 2 xxup xxunk can be used to search for information
#  y: EmptyLabelList
#  ,,,,
#  Path: /content, [0, 1])

# %%
#data.vocab.itos[:50]
#data.vocab.stoi
#len(data.vocab.itos)
#t1 = data.train_ds[500][0] 
#t1
#t2 = data.train_ds[500][1]
#t2

# %% [markdown]
# #Classifier

# %%
learn_classifier = text_classifier_learner(data , AWD_LSTM, drop_mult=0)

# %%
learn_classifier.lr_find()
# Out:
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
learn_classifier.recorder.plot()

# %% [markdown]
# ##Training

# %%
learn_classifier.fit_one_cycle(2, 1e-04, moms=(0.8,0.7))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.723233</td>
#       <td>0.716186</td>
#       <td>0.512000</td>
#       <td>00:09</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.692901</td>
#       <td>0.706421</td>
#       <td>0.521000</td>
#       <td>00:09</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn_classifier.save("First")
learn_classifier.load('First');

# %%
learn_classifier.recorder.plot_losses()

# %%
learn_classifier.model
# Out:
# SequentialRNN(
#   (0): MultiBatchEncoder(
#     (module): AWD_LSTM(
#       (encoder): Embedding(5536, 400, padding_idx=1)
#       (encoder_dp): EmbeddingDropout(
#         (emb): Embedding(5536, 400, padding_idx=1)
#       )
#       (rnns): ModuleList(
#         (0): WeightDropout(
#           (module): LSTM(400, 1152, batch_first=True)
#         )
#         (1): WeightDropout(
#           (module): LSTM(1152, 1152, batch_first=True)
#         )
#         (2): WeightDropout(
#           (module): LSTM(1152, 400, batch_first=True)
#         )
#       )
#       (input_dp): RNNDropout()
#       (hidden_dps): ModuleList(
#         (0): RNNDropout()
#         (1): RNNDropout()
#         (2): RNNDropout()
#       )
#     )
#   )
#   (1): PoolingLinearClassifier(
#     (layers): Sequential(
#       (0): BatchNorm1d(1200, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (1): Linear(in_features=1200, out_features=50, bias=True)
#       (2): ReLU(inplace=True)
#       (3): BatchNorm1d(50, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (4): Dropout(p=0.1, inplace=False)
#       (5): Linear(in_features=50, out_features=2, bias=True)
#     )
#   )
# )

# %%
learn_classifier.unfreeze()
learn_classifier.summary()
# Out:
# SequentialRNN
# ======================================================================
# Layer (type)         Output Shape         Param #    Trainable
# ======================================================================
# RNNDropout           [61, 400]            0          False
# ______________________________________________________________________
# RNNDropout           [61, 1152]           0          False
# ______________________________________________________________________
# RNNDropout           [61, 1152]           0          False
# ______________________________________________________________________
# BatchNorm1d          [1200]               2,400      True
# ______________________________________________________________________
# Linear               [50]                 60,050     True
# ______________________________________________________________________
# ReLU                 [50]                 0          False
# ______________________________________________________________________
# BatchNorm1d          [50]                 100        True
# ______________________________________________________________________
# Dropout              [50]                 0          False
# ______________________________________________________________________
# Linear               [2]                  102        True
# ______________________________________________________________________
#
# Total params: 62,652
# Total trainable params: 62,652
# Total non-trainable params: 0
# Optimized with 'torch.optim.adam.Adam', betas=(0.9, 0.99)
# Using true weight decay as discussed in https://www.fast.ai/2018/07/02/adam-weight-decay/
# Loss function : FlattenedLoss
# ======================================================================
# Callbacks functions applied
#     RNNTrainer

# %%
for index, layer in enumerate(learn_classifier.layer_groups):
  print('Layer Group Index: ', index, layer)
# Out:
# Layer Group Index:  0 Sequential(
#   (0): Embedding(5536, 400, padding_idx=1)
#   (1): EmbeddingDropout(
#     (emb): Embedding(5536, 400, padding_idx=1)
#   )
# )
# Layer Group Index:  1 Sequential(
#   (0): WeightDropout(
#     (module): LSTM(400, 1152, batch_first=True)
#   )
#   (1): RNNDropout()
# )
# Layer Group Index:  2 Sequential(
#   (0): WeightDropout(
#     (module): LSTM(1152, 1152, batch_first=True)
#   )
#   (1): RNNDropout()
# )
# Layer Group Index:  3 Sequential(
#   (0): WeightDropout(
#     (module): LSTM(1152, 400, batch_first=True)
#   )
#   (1): RNNDropout()
# )
# Layer Group Index:  4 Sequential(
#   (0): PoolingLinearClassifier(
#     (layers): Sequential(
#       (0): BatchNorm1d(1200, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (1): Linear(in_features=1200, out_features=50, bias=True)
#       (2): ReLU(inplace=True)
#       (3): BatchNorm1d(50, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (4): Dropout(p=0.1, inplace=False)
#       (5): Linear(in_features=50, out_features=2, bias=True)
#     )
#   )
# )

# %%
def summary_trainable(learner):
  result = []
  total_params_element = 0
  def check_trainable(module):
    nonlocal total_params_element
    if len(list(module.children())) == 0:
      num_param = 0
      num_trainable_param = 0
      num_param_numel = 0
      for parameter in module.parameters():
        num_param += 1
        if parameter.requires_grad:
          num_param_numel += parameter.numel()
          total_params_element += parameter.numel()
          num_trainable_param += 1

      result.append({'module': module, 'num_param': num_param , 'num_trainable_param' : num_trainable_param, 'num_param_numel': num_param_numel})
  learner.model.apply(check_trainable)
  
  print("{: <85} {: <17} {:,<20} {: <40}".format('Module Name', 'Total Parameters', 'Trainable Parameters', '# Elements in Trainable Parametrs'))
  for row in result:
    print("{: <85} {: <17} {: <20} {: <40,}".format(row['module'].__str__(), row['num_param'], row['num_trainable_param'], row['num_param_numel']))
  print('Total number of parameters elements {:,}'.format(total_params_element))

# %%
learn_classifier.freeze()
summary_trainable(learn_classifier)
# Out:
# Module Name                                                                           Total Parameters  Trainable Parameters # Elements in Trainable Parametrs
# Embedding(5536, 400, padding_idx=1)                                                   1                 0                    0
# Embedding(5536, 400, padding_idx=1)                                                   1                 0                    0
# LSTM(400, 1152, batch_first=True)                                                     4                 0                    0
# LSTM(1152, 1152, batch_first=True)                                                    4                 0                    0
# LSTM(1152, 400, batch_first=True)                                                     4                 0                    0
# RNNDropout()                                                                          0                 0                    0
# RNNDropout()                                                                          0                 0                    0
# RNNDropout()                                                                          0                 0                    0
# RNNDropout()                                                                          0                 0                    0
# BatchNorm1d(1200, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)     2                 2                    2,400
# Linear(in_features=1200, out_features=50, bias=True)                                  2                 2                    60,050
# ReLU(inplace=True)                                                                    0                 0                    0
# BatchNorm1d(50, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)       2                 2                    100
# Dropout(p=0.1, inplace=False)                                                         0                 0                    0
# Linear(in_features=50, out_features=2, bias=True)                                     2                 2                    102
# Total number of parameters elements 62,652

# %%
learn_classifier.freeze()
learn_classifier.freeze_to(-1)
summary_trainable(learn_classifier)
# Out:
# Module Name                                                                           Total Parameters  Trainable Parameters # Elements in Trainable Parametrs
# Embedding(5536, 400, padding_idx=1)                                                   1                 0                    0
# Embedding(5536, 400, padding_idx=1)                                                   1                 0                    0
# LSTM(400, 1152, batch_first=True)                                                     4                 0                    0
# LSTM(1152, 1152, batch_first=True)                                                    4                 0                    0
# LSTM(1152, 400, batch_first=True)                                                     4                 0                    0
# RNNDropout()                                                                          0                 0                    0
# RNNDropout()                                                                          0                 0                    0
# RNNDropout()                                                                          0                 0                    0
# RNNDropout()                                                                          0                 0                    0
# BatchNorm1d(1200, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)     2                 2                    2,400
# Linear(in_features=1200, out_features=50, bias=True)                                  2                 2                    60,050
# ReLU(inplace=True)                                                                    0                 0                    0
# BatchNorm1d(50, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)       2                 2                    100
# Dropout(p=0.1, inplace=False)                                                         0                 0                    0
# Linear(in_features=50, out_features=2, bias=True)                                     2                 2                    102
# Total number of parameters elements 62,652

# %%
learn_classifier.freeze()
learn_classifier.freeze_to(-2)
summary_trainable(learn_classifier)
# Out:
# Module Name                                                                           Total Parameters  Trainable Parameters # Elements in Trainable Parametrs
# Embedding(5536, 400, padding_idx=1)                                                   1                 0                    0
# Embedding(5536, 400, padding_idx=1)                                                   1                 0                    0
# LSTM(400, 1152, batch_first=True)                                                     4                 0                    0
# LSTM(1152, 1152, batch_first=True)                                                    4                 0                    0
# LSTM(1152, 400, batch_first=True)                                                     4                 4                    2,486,400
# RNNDropout()                                                                          0                 0                    0
# RNNDropout()                                                                          0                 0                    0
# RNNDropout()                                                                          0                 0                    0
# RNNDropout()                                                                          0                 0                    0
# BatchNorm1d(1200, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)     2                 2                    2,400
# Linear(in_features=1200, out_features=50, bias=True)                                  2                 2                    60,050
# ReLU(inplace=True)                                                                    0                 0                    0
# BatchNorm1d(50, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)       2                 2                    100
# Dropout(p=0.1, inplace=False)                                                         0                 0                    0
# Linear(in_features=50, out_features=2, bias=True)                                     2                 2                    102
# Total number of parameters elements 2,549,052

# %%
learn_classifier.freeze()
learn_classifier.freeze_to(-3)
summary_trainable(learn_classifier)
# Out:
# Module Name                                                                           Total Parameters  Trainable Parameters # Elements in Trainable Parametrs
# Embedding(5536, 400, padding_idx=1)                                                   1                 0                    0
# Embedding(5536, 400, padding_idx=1)                                                   1                 0                    0
# LSTM(400, 1152, batch_first=True)                                                     4                 0                    0
# LSTM(1152, 1152, batch_first=True)                                                    4                 4                    10,626,048
# LSTM(1152, 400, batch_first=True)                                                     4                 4                    2,486,400
# RNNDropout()                                                                          0                 0                    0
# RNNDropout()                                                                          0                 0                    0
# RNNDropout()                                                                          0                 0                    0
# RNNDropout()                                                                          0                 0                    0
# BatchNorm1d(1200, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)     2                 2                    2,400
# Linear(in_features=1200, out_features=50, bias=True)                                  2                 2                    60,050
# ReLU(inplace=True)                                                                    0                 0                    0
# BatchNorm1d(50, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)       2                 2                    100
# Dropout(p=0.1, inplace=False)                                                         0                 0                    0
# Linear(in_features=50, out_features=2, bias=True)                                     2                 2                    102
# Total number of parameters elements 13,175,100

# %%
learn_classifier.freeze()
learn_classifier.freeze_to(-4)
summary_trainable(learn_classifier)
# Out:
# Module Name                                                                           Total Parameters  Trainable Parameters # Elements in Trainable Parametrs
# Embedding(5536, 400, padding_idx=1)                                                   1                 0                    0
# Embedding(5536, 400, padding_idx=1)                                                   1                 0                    0
# LSTM(400, 1152, batch_first=True)                                                     4                 4                    7,160,832
# LSTM(1152, 1152, batch_first=True)                                                    4                 4                    10,626,048
# LSTM(1152, 400, batch_first=True)                                                     4                 4                    2,486,400
# RNNDropout()                                                                          0                 0                    0
# RNNDropout()                                                                          0                 0                    0
# RNNDropout()                                                                          0                 0                    0
# RNNDropout()                                                                          0                 0                    0
# BatchNorm1d(1200, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)     2                 2                    2,400
# Linear(in_features=1200, out_features=50, bias=True)                                  2                 2                    60,050
# ReLU(inplace=True)                                                                    0                 0                    0
# BatchNorm1d(50, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)       2                 2                    100
# Dropout(p=0.1, inplace=False)                                                         0                 0                    0
# Linear(in_features=50, out_features=2, bias=True)                                     2                 2                    102
# Total number of parameters elements 20,335,932

# %%
learn_classifier.freeze()
learn_classifier.freeze_to(-5) # equal to unfreeze
summary_trainable(learn_classifier)
# Out:
# Module Name                                                                           Total Parameters  Trainable Parameters # Elements in Trainable Parametrs
# Embedding(5536, 400, padding_idx=1)                                                   1                 1                    2,214,400
# Embedding(5536, 400, padding_idx=1)                                                   1                 1                    2,214,400
# LSTM(400, 1152, batch_first=True)                                                     4                 4                    7,160,832
# LSTM(1152, 1152, batch_first=True)                                                    4                 4                    10,626,048
# LSTM(1152, 400, batch_first=True)                                                     4                 4                    2,486,400
# RNNDropout()                                                                          0                 0                    0
# RNNDropout()                                                                          0                 0                    0
# RNNDropout()                                                                          0                 0                    0
# RNNDropout()                                                                          0                 0                    0
# BatchNorm1d(1200, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)     2                 2                    2,400
# Linear(in_features=1200, out_features=50, bias=True)                                  2                 2                    60,050
# ReLU(inplace=True)                                                                    0                 0                    0
# BatchNorm1d(50, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)       2                 2                    100
# Dropout(p=0.1, inplace=False)                                                         0                 0                    0
# Linear(in_features=50, out_features=2, bias=True)                                     2                 2                    102
# Total number of parameters elements 24,764,732

# %%
learn_classifier.freeze()
learn_classifier.unfreeze()
summary_trainable(learn_classifier)
# Out:
# Module Name                                                                           Total Parameters  Trainable Parameters # Elements in Trainable Parametrs
# Embedding(5536, 400, padding_idx=1)                                                   1                 1                    2,214,400
# Embedding(5536, 400, padding_idx=1)                                                   1                 1                    2,214,400
# LSTM(400, 1152, batch_first=True)                                                     4                 4                    7,160,832
# LSTM(1152, 1152, batch_first=True)                                                    4                 4                    10,626,048
# LSTM(1152, 400, batch_first=True)                                                     4                 4                    2,486,400
# RNNDropout()                                                                          0                 0                    0
# RNNDropout()                                                                          0                 0                    0
# RNNDropout()                                                                          0                 0                    0
# RNNDropout()                                                                          0                 0                    0
# BatchNorm1d(1200, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)     2                 2                    2,400
# Linear(in_features=1200, out_features=50, bias=True)                                  2                 2                    60,050
# ReLU(inplace=True)                                                                    0                 0                    0
# BatchNorm1d(50, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)       2                 2                    100
# Dropout(p=0.1, inplace=False)                                                         0                 0                    0
# Linear(in_features=50, out_features=2, bias=True)                                     2                 2                    102
# Total number of parameters elements 24,764,732
